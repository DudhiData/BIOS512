# %% [markdown]
# # Homework 03 - Nonstandard Evaluation and Git
#
# ## Nonstandard Evaluation

# %% [markdown]
# ### Question 1
# Imagine we have a data frame called `data`, with a `type` column. Which one works and why?\
# Function 1:
# ```
# group_and_tally <- function(df, column){
#     df %>% group_by({{ column }}) %>% tally();
# }
# group_and_tally(data, type);
# ```
#
# Function 2:
# ```
# group_and_tally <- function(df, column){
#     df %>% group_by(column) %>% tally();
# }
# group_and_tally(data, type);
# ```

# %% [markdown]
# Function 1 works while Function 2 doesn't because in the environment of the function, when you call the group_by function on 'df' and pass in 'column', the issue becomes that R tries to look for the column named 'column' in df, which will cause an error in Function 2. In function 1, the {{}} makes use of nonstandard evaluation and passes the column parameter instead of the column name 'column' into the group_by function, which will correctly perform group_by on 'df'.

# %% [markdown]
# ## Git
# For the questions below, please add the commands you used to complete these steps.
#
# ### Question 2
# Set up your git repo on your local computer. If you already make a git repo on GitHub, but it isn’t on your local computer - clone it.

# %% [markdown]
# git clone git@github.com:DudhiData/BIOS512.git

# %% [markdown]
# ### Question 3
# Set up your SSH key.

# %% [markdown]
# git config --global user.name "DHRUV"
# git config --global user.email "dbad@unc.edu"
# ssh-keygen -t ed25519 -C "dbad@unc.edu"
# eval "$(ssh-agent -s)"
# ssh-add ~/.ssh/id_ed25519v
# cat ~/.ssh/id_ed25519.pub
# ssh -T git@github.com

# %% [markdown]
# ### Question 4
# a) Add a HW2 directory to your git repo through the terminal with a HW.md file that says "This is for homework 2."

# %% [markdown]
# b) *Add* HW2.md to the staging area. Then, use the command to see which files have been modified, staged for commit, or are untracked. What does it show?
# They should copy paste the terminal response after git status, and show that key used the commands below.

# %% [markdown]
# c) Save file changes to the main branch.

# %% [markdown]
# d) Now, edit the HW2.md file to give it a title.

# %% [markdown]
# e) Use the command that compares current, unsaved changes to the main branch. What does it say?\
# \
# f) Use the command that checks the status of the working directory and the staging area *again*. What does it say?\
# \
# g) Once again, add HW2.md to the staging area and save the file changes to the main branch. Then, get use the command that gives you project history and paste the output in your homework.

# %% [markdown]
# h) Do some searching... What `git` command will provide you documentation on other commands? Use that command to find documentation on `git log` and `git show`. What does `--since` mean in regards to `git log`? Copy and paste what is written in the documentation.

# %% [markdown]
# a)
# cd ~/CLASSES/BIOS512
# mkdir HW2
# cd HW2
# touch HW2.md
# echo "This is for homework 2." >> HW2.md
#
# b)
# git add HW2.md
# git status (shows us that HW2.md is a file change that is staged for a commit, while there are currently no other changes not staged for a commit and that the current branch is caught up to main)
#
# c)
# git commit -m "HW2.md created."
#
# d)
# cat < <EOF> <HW2.md>
# \# Title
# HW2 MD FILE
# EOF
#
# e)
# git diff
# It shows a +HW2 MD FILE for HW2.md.
#
# f)
# git status
# It says that HW2/HW2.md has a change that hasn't been committed yet.
#
# g)
# git log
# commit 70987b5fd65a3205b382d42778e5307601944994 (HEAD -> main, origin/main, origin/HEAD)
# Author: DHRUV <dbad@unc.edu>
# Date:   Thu Sep 11 16:21:02 2025 -0400
#
#     HW2.md titling.
#
# commit acebf3296fb4ba137c52a195da3bba1de905acf3
# Author: DHRUV <dbad@unc.edu>
# Date:   Thu Sep 11 16:17:12 2025 -0400
#
#     HW2.md titling.
#
# commit ca548b30c4399246943ce4965b46ac82d0225463
# Author: DHRUV <dbad@unc.edu>
# Date:   Thu Sep 11 16:01:00 2025 -0400
#
#     HW2 stuff.
#
# commit dfdb840d467dfefcb4d3f6080e78ed7b5dcdd561
# Author: dbad <dbad@unc.edu>
# Date:   Thu Sep 11 15:58:47 2025 -0400
#
# :
# commit 70987b5fd65a3205b382d42778e5307601944994 (HEAD -> main, origin/main, origin/HEAD)
# Author: DHRUV <dbad@unc.edu>
# Date:   Thu Sep 11 16:21:02 2025 -0400
#
#     HW2.md titling.
#
# commit acebf3296fb4ba137c52a195da3bba1de905acf3
# Author: DHRUV <dbad@unc.edu>
# Date:   Thu Sep 11 16:17:12 2025 -0400
#
#     HW2.md titling.
#
# commit ca548b30c4399246943ce4965b46ac82d0225463
# Author: DHRUV <dbad@unc.edu>
# Date:   Thu Sep 11 16:01:00 2025 -0400
#
#     HW2 stuff.
#
# commit dfdb840d467dfefcb4d3f6080e78ed7b5dcdd561
# Author: dbad <dbad@unc.edu>
# Date:   Thu Sep 11 15:58:47 2025 -0400
#
#     Create README.md
#
# commit d59966dd4bcc581a0f929e050f497f9dafda70f5
# Author: DHRUV <dbad@unc.edu>
# Date:   Thu Sep 11 15:53:04 2025 -0400
#
#     Cleaned directory.
#
# commit 2df43c0335b9fab20482dd5581732b19f8416399
# Author: DHRUV <dbad@unc.edu>
# Date:   Thu Sep 11 15:47:33 2025 -0400
#
#     Directory cleanup.
#
# commit 9d5a702f657c5e13f0a6e7a8d8f20be5ed097b9f
# Author: DHRUV <dbad@unc.edu>
# Date:   Thu Sep 11 15:15:38 2025 -0400
#
#     Directory cleanup.
#
# commit 19fe1c3305cfea7915851eb9639a2d6aaf26f4b9
# Author: DHRUV <dbad@unc.edu>
# Date:   Thu Sep 11 15:10:35 2025 -0400
#
#     HW2 stuff.
#
# commit 67c2d875640fb301f587e83d4c1cb56c0f0d2583
# Author: dbad <dbad@unc.edu>
# Date:   Wed Sep 10 12:15:57 2025 -0400
#
#     Add files via upload
#
# commit 9653aaec17aa4480a90b67f47f153fae555be2cb
# Author: dbad <dbad@unc.edu>
# Date:   Mon Sep 8 08:14:16 2025 -0400
#
#     Add files via upload
#
# commit b433ed3300f0ce2cf75a3258ba987ae8d86a7179
# Author: dbad <dbad@unc.edu>
# Date:   Tue Sep 2 14:53:45 2025 -0400
#
#     Add files via upload
#
# commit 5056df45dd7e4d5510da602f6bf83d7f1ed4bf4f
# Author: dbad <dbad@unc.edu>
# Date:   Tue Sep 2 14:53:34 2025 -0400
#
#     Delete Homework/BIOS512_HW2-1 (4).ipynb
#
# commit 1309a40d8c1360c31e168b2fbcec904a177bce61
# Author: dbad <dbad@unc.edu>
# Date:   Tue Sep 2 14:27:13 2025 -0400
#
#     Add files via upload
#
# commit c268d718c39921cb65ea402af075bd03d688c318
# Author: dbad <dbad@unc.edu>
# Date:   Tue Sep 2 14:27:01 2025 -0400
#
#     Delete Homework/BIOS512_HW2-1 (2) (1).ipynb
#
# commit b7e6944b26ce79fefdf25e0cf488c6d5ec7fff2d
# Author: dbad <dbad@unc.edu>
# Date:   Mon Sep 1 13:32:42 2025 -0400
#
#     Add files via upload
#
# commit a812ed40811e40182dc5bf9c368494aa8e477d39
# Author: dbad <dbad@unc.edu>
# Date:   Mon Sep 1 13:32:32 2025 -0400
#
#     Delete Homework/BIOS512_HW2-1 (2).ipynb
#
# commit 1215e5a26e5d62a52072b21329341aa478f423c5
# Author: dbad <dbad@unc.edu>
# Date:   Mon Sep 1 13:30:45 2025 -0400
#
#     Add files via upload
#
# commit 94f061f6b82cf13590d8b1b9777ebbf1887e6604
# Author: dbad <dbad@unc.edu>
# Date:   Sat Aug 30 14:16:31 2025 -0400
#
#     Add files via upload
#
# commit 74a081d1a13a3103dffd4eb88cf74505db4fbff8
# Author: dbad <dbad@unc.edu>
# Date:   Sat Aug 30 14:16:17 2025 -0400
#
#     Delete Homework/BIOS512_HW2-1.ipynb
#
# commit a542b6db5c90bc19b3e3b28f59c0ab079a0ed2bd
# Author: dbad <dbad@unc.edu>
# Date:   Thu Aug 28 14:05:33 2025 -0400
#
#     Add files via upload
#
# commit 1c963779efb0b06ba48c7795a12b9f92d9174602
# Author: dbad <dbad@unc.edu>
# Date:   Thu Aug 28 14:05:11 2025 -0400
#
#     Delete BIOS512_HW2-1.ipynb
#
# commit dd28402bbf243048767772a67d8c658a73f23966
# Author: dbad <dbad@unc.edu>
# Date:   Thu Aug 28 13:58:46 2025 -0400
#
#     Create Homework 01
#
# commit a520a54a2da97294acdfe7e5272d243bb5b45bcd
# Author: dbad <dbad@unc.edu>
# Date:   Thu Aug 28 13:55:26 2025 -0400
#
#     Add files via upload
#
# commit 5899c4a8e52b12f4f331fb44b815ef47e2d9f2af
# Author: dbad <dbad@unc.edu>
# Date:   Thu Aug 28 01:13:18 2025 -0400
#
#     Create install.R
#
# commit e14e35e40e21e4a5c15c50bffb41dcfcc522a479
# Author: dbad <dbad@unc.edu>
# Date:   Thu Aug 28 01:10:09 2025 -0400
#
#     Create runtime.txt
#
# commit 28b3ede5481a851321547b5bfa4e2b933264e321
# Author: dbad <dbad@unc.edu>
# Date:   Thu Aug 28 01:09:00 2025 -0400
#
#     Create hello.R
#
# commit 7f2e5ffbf41acaf5432ff10fa58278cf60ecac01
# Author: Dhruv Dudhat <dbad@unc.edu>
# Date:   Thu Aug 28 01:07:21 2025 -0400
#
#     initial commit
#
# h) git help <command>
# git log documentation:
# file:///C:/Program%20Files/Git/mingw64/share/doc/git-doc/git-log.html
# git show documentation:
# file:///C:/Program%20Files/Git/mingw64/share/doc/git-doc/git-show.html
#
# --since only shows the git log history only after the specified date.
# Documentation: --since=<date>. Show commits more recent than a specific date.

# %% [markdown]
# ## Tidyverse
#
# Note: Please make sure Binder is set up correctly to run this section. You can follow the instructions here: https://github.com/rjenki/BIOS512.

# %% [markdown]
# **Please show your code for this section!** Before completing this section, please run the following.

# %%
library(tidyverse)
if (!dir.exists("intermediate")) dir.create("intermediate", recursive = TRUE)
if (!exists("mdpre")) mdpre <- function(x) { print(x) }
if (!exists("ggmd"))  ggmd  <- function(p) { print(p) }

# %% [markdown]
# ### Question 5
#
# Download the patient_names.csv and patient_properties.csv files from Canvas and read them into R. Manually set the date columns to be date variables. Print the first 10 observations of each.

# %%
names <- read_csv("patient_names.csv", col_types = cols(BIRTHDATE = col_date(), DEATHDATE = col_date()));
properties <- read_csv("patient_properties.csv");
head(names, 10);
head(properties, 10);
# Out:
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Rows: 3896 Columns: 3
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): ID, property, value
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#    ID                                   BIRTHDATE DEATHDATE FIRST
# 1  5605b66b-e92d-c16c-1b83-b8bf7040d51f <NA>      <NA>      Nikita578
# 2  6e5ae27c-8038-7988-e2c0-25a103f01bfa <NA>      <NA>      Zane918
# 3  8123d076-0886-9007-e956-d5864aa121a7 <NA>      <NA>      Quinn173
# 4  770518e4-6133-648e-60c9-071eb2f0e2ce <NA>      <NA>      Abel832
# 5  f96addf5-81b9-0aab-7855-d208d3d352c5 <NA>      <NA>      Edwin773
# 6  8e9650d1-788a-78f9-4a28-d08f7f95354a <NA>      <NA>      Frankie174
# ...

# %% [markdown]
# ### Question 6
# In the data frame pulled from patient_properties, you'll notice that the data is long, not wide. Do a pivot to make the properties their own columns. Print the first 10 observations after you do so.

# %%
wide_properties <- properties %>% pivot_wider(id_cols = ID, names_from = property);
head(wide_properties, 10);
# Out:
#    ID                                   MARITAL RACE   ETHNICITY   GENDER
# 1  5605b66b-e92d-c16c-1b83-b8bf7040d51f M       white  nonhispanic F
# 2  6e5ae27c-8038-7988-e2c0-25a103f01bfa M       white  nonhispanic M
# 3  8123d076-0886-9007-e956-d5864aa121a7 M       white  nonhispanic M
# 4  770518e4-6133-648e-60c9-071eb2f0e2ce M       white  hispanic    M
# 5  f96addf5-81b9-0aab-7855-d208d3d352c5 M       white  hispanic    M
# 6  8e9650d1-788a-78f9-4a28-d08f7f95354a M       white  hispanic    M
# 7  183df435-4190-060e-8f8e-bf63c572b266 M       asian  nonhispanic F
# 8  720560d4-51da-c38c-ee90-c15935278df1 M       white  nonhispanic M
# 9  217851b0-5f47-d376-18b9-0fe4ba77207e S       black  hispanic    M
# 10 ff331e5c-ab16-e218-f39a-63e11de1ed75 M       native hispanic    M

# %% [markdown]
# ### Question 7
# Perform a left join of the names and properties_wide data frames by the ID column and print the first 10 rows.

# %%
joined_names <- names %>% left_join(wide_properties, by = "ID");
head(joined_names, 10);
# Out:
#    ID                                   BIRTHDATE DEATHDATE FIRST
# 1  5605b66b-e92d-c16c-1b83-b8bf7040d51f <NA>      <NA>      Nikita578
# 2  6e5ae27c-8038-7988-e2c0-25a103f01bfa <NA>      <NA>      Zane918
# 3  8123d076-0886-9007-e956-d5864aa121a7 <NA>      <NA>      Quinn173
# 4  770518e4-6133-648e-60c9-071eb2f0e2ce <NA>      <NA>      Abel832
# 5  f96addf5-81b9-0aab-7855-d208d3d352c5 <NA>      <NA>      Edwin773
# 6  8e9650d1-788a-78f9-4a28-d08f7f95354a <NA>      <NA>      Frankie174
# 7  183df435-4190-060e-8f8e-bf63c572b266 <NA>      <NA>      Eilene124
# 8  720560d4-51da-c38c-ee90-c15935278df1 <NA>      <NA>      Lowell343
# 9  217851b0-5f47-d376-18b9-0fe4ba77207e <NA>      <NA>      Adrian111
# 10 ff331e5c-ab16-e218-f39a-63e11de1ed75 <NA>      <NA>      Eugene421
#    LAST           CITY      STATE         MARITAL RACE   ETHNICITY   GENDER
# 1  Erdman779      Quincy    Massachusetts M       white  nonhispanic F
# ...

# %% [markdown]
# ### Question 8
# Notice something interesting about the names in our data set. Fix the name formatting and print the first 10 observations.

# %%
joined_names$FIRST <- gsub("[0-9]", "", joined_names$FIRST);
joined_names$LAST <- gsub("[0-9]", "", joined_names$LAST);
head(joined_names, 10);
# Out:
#    ID                                   BIRTHDATE DEATHDATE FIRST   LAST
# 1  5605b66b-e92d-c16c-1b83-b8bf7040d51f <NA>      <NA>      Nikita  Erdman
# 2  6e5ae27c-8038-7988-e2c0-25a103f01bfa <NA>      <NA>      Zane    Hodkiewicz
# 3  8123d076-0886-9007-e956-d5864aa121a7 <NA>      <NA>      Quinn   Marquardt
# 4  770518e4-6133-648e-60c9-071eb2f0e2ce <NA>      <NA>      Abel    Smitham
# 5  f96addf5-81b9-0aab-7855-d208d3d352c5 <NA>      <NA>      Edwin   Labadie
# 6  8e9650d1-788a-78f9-4a28-d08f7f95354a <NA>      <NA>      Frankie Oberbrunner
# 7  183df435-4190-060e-8f8e-bf63c572b266 <NA>      <NA>      Eilene  Walsh
# 8  720560d4-51da-c38c-ee90-c15935278df1 <NA>      <NA>      Lowell  Price
# 9  217851b0-5f47-d376-18b9-0fe4ba77207e <NA>      <NA>      Adrian  Gleason
# 10 ff331e5c-ab16-e218-f39a-63e11de1ed75 <NA>      <NA>      Eugene  Abernathy
#    CITY      STATE         MARITAL RACE   ETHNICITY   GENDER
# 1  Quincy    Massachusetts M       white  nonhispanic F
# ...

# %% [markdown]
# ### Question 9
# Using a for statement to loop through the categorical variables (excluding name and ID), print the counts of each unique value in descending order, using the mdpre() function for formatting.

# %%
selected_columns <- joined_names %>% select(-ID, -FIRST, -LAST);
distinct_col <- selected_columns %>% unique();
i <- 1;
for (column in distinct_col) {
    counts <- table({{column}});
    sorted_counts <- sort(counts, decreasing = TRUE);
    mdpre(sorted_counts);
    i<<- i+1;
}
# Out:
# integer(0)
# integer(0)
#
#         Boston         Quincy        Chelsea         Revere       Winthrop
#             44             16             15             14             13
#        Everett      Cambridge       Weymouth        Medford     Somerville
#             10              9              9              8              8
#        Hingham      Brookline       Cohasset         Newton       Scituate
#              6              5              5              5              5
#      Braintree         Malden           Hull North Scituate       Stoneham
#              4              4              3              3              3
#        Belmont      Lynnfield        Melrose         Milton        Norwell
#              1              1              1              1              1
#        Reading        Waltham      Watertown     Winchester
#              1              1              1              1
# Massachusetts
#           198
#
#    M    S Fine male
#  131   64    1    1
# ...

# %% [markdown]
# ### Question 10
# If you see any weird values, get rid of the ones that don't make sense, and combine the ones that are formatted wrong. Don't forget ot check the dates! Print the new tables for categorical values, and print the date ranges.

# %%
# Cleaning
joined_names$ETHNICITY[joined_names$ETHNICITY == "nonhispani"] <- "nonhispanic";
joined_names$ETHNICITY[joined_names$ETHNICITY == "hispani"] <- "hispanic";
joined_names$GENDER[joined_names$GENDER == "female"] <- "F";
joined_names$GENDER[joined_names$GENDER == "Female"] <- "F";
joined_names$GENDER[joined_names$GENDER == "Male"] <- "M";
joined_names$RACE[joined_names$RACE == "asiann"] <- "asian";
joined_names$MARITAL[joined_names$MARITAL == "Fine"] <- NA;
joined_names$MARITAL[joined_names$MARITAL == "male"] <- NA; 

# Date Formatting
names <- read_csv("patient_names.csv");
dates <- mdy(names$BIRTHDATE);
corrected_dates <- if_else(year(dates) > 2020, dates - years(100), dates)
corrected_dates <- format(corrected_dates, "%m/%d/%Y") %>% as.Date(format = "%m/%d/%Y");
joined_names$BIRTHDATE <- corrected_dates;
joined_names$DEATHDATE <- format(mdy(names$DEATHDATE), "%m/%d/%Y") %>% as.Date(format = "%m/%d/%Y");



selected_columns <- joined_names %>% select(-ID, -FIRST, -LAST);
distinct_col <- selected_columns %>% unique();
i <- 1;
for (column in distinct_col) {
    counts <- table({{column}});
    sorted_counts <- sort(counts, decreasing = TRUE);
    mdpre(sorted_counts);
    i<<- i+1;
}
# Out:
# Rows: 974 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (7): ID, BIRTHDATE, DEATHDATE, FIRST, LAST, CITY, STATE
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# 1925-11-17 1927-04-22 1929-01-28 1929-05-15 1936-01-12 1925-08-10 1925-11-16
#          4          4          4          4          4          3          3
# 1926-08-07 1927-02-05 1928-11-04 1928-12-25 1930-11-03 1933-08-24 1922-05-31
#          3          3          3          3          3          3          2
# 1923-09-22 1925-01-15 1925-02-09 1925-05-10 1925-06-01 1925-11-20 1926-07-14
#          2          2          2          2          2          2          2
# 1926-12-27 1927-06-04 1927-09-08 1927-10-16 1929-06-30 1929-10-14 1930-04-25
#          2          2          2          2          2          2          2
# ...

# %% [markdown]
# ### Question 11
# Make a histogram of the ages of patients by gender.

# %%
library(ggplot2);
birth_year <- format(joined_names$BIRTHDATE, "%Y") %>% as.numeric();
death_year <- format(joined_names$DEATHDATE, "%Y") %>% as.numeric();
age <- as.integer(death_year - birth_year);
joined_names$AGE <- age;
ggplot(joined_names %>% filter(!is.na(AGE)), aes(x = AGE, fill = GENDER)) +
geom_histogram(stat = 'count', position = 'dodge') + labs(x="Age",y="Count",title="Gender and Age in Patients");
# Out:
# Warning message in geom_histogram(stat = "count", position = "dodge"):
# “Ignoring unknown parameters: `binwidth` and `bins`”
# plot without title

# %% [markdown]
# ### Question 12
# Make a scatterplot of birthdate by martial status.

# %%
ggplot(joined_names %>% filter(!is.na(MARITAL)), aes(x = BIRTHDATE, y = MARITAL, color = MARITAL)) +
geom_jitter(alpha = 0.6, width = 0.2, height = 0.2) + labs(x="Birthdate",y="Marital Status",title="Patient Birthdates by Marital Status");
# Out:
# plot without title
